# %% [markdown]
# ##           Prospective areas to set-up a Gym in New York

# %% [markdown]
# #### Install libraries.

# %%
# !conda install -c conda-forge geopy --yes
# Out:
# Solving environment: done
#
# # All requested packages already installed.

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         713 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.1.0-py_1 conda-forge
#     branca:  0.4.0-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# #### Import Libraries.

# %%
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import pandas as pd
# Set pandas options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', -1)

import json # library to handle JSON files
from pandas.io.json import json_normalize

import folium # map rendering library

import requests

import numpy as np

# import k-means from clustering stage
from sklearn.cluster import KMeans

from sklearn import metrics

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
from matplotlib.pyplot import subplots

from sklearn import preprocessing

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### Download and Explore dataset

# %% [markdown]
# Neighborhood has a total of 5 boroughs and 306 neighborhoods. In order to segement the neighborhoods and explore them, we will essentially need a dataset that contains the 5 boroughs and the neighborhoods that exist in each borough as well as the the latitude and logitude coordinates of each neighborhood.
#
# This dataset exists for free on the web. The link to the dataset: https://geo.nyu.edu/catalog/nyu_2451_34572

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded!')
# Out:
# Data downloaded!

# %% [markdown]
# #### Load and Explore the data

# %%
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %%
neighborhoods_data = newyork_data['features']
neighborhoods_data[0]
# Out:
# {'type': 'Feature',
#  'id': 'nyu_2451_34572.1',
#  'geometry': {'type': 'Point',
#   'coordinates': [-73.84720052054902, 40.89470517661]},
#  'geometry_name': 'geom',
#  'properties': {'name': 'Wakefield',
#   'stacked': 1,
#   'annoline1': 'Wakefield',
#   'annoline2': None,
#   'annoline3': None,
#   'annoangle': 0.0,
#   'borough': 'Bronx',
#   'bbox': [-73.84720052054902,
#    40.89470517661,
#    -73.84720052054902,
#    40.89470517661]}}

# %% [markdown]
# #### Transform the data into pandas dataset

# %% [markdown]
# The next task is essentially transforming this data of nested Python dictionaries into a *pandas* dataframe. So let's start by creating an empty dataframe.

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# %% [markdown]
# Then let's loop through the data and fill the dataframe one row at a time.

# %%
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
    

neighborhoods.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0  Bronx   Wakefield    40.894705 -73.847201
# 1  Bronx   Co-op City   40.874294 -73.829939
# 2  Bronx   Eastchester  40.887556 -73.827806
# 3  Bronx   Fieldston    40.895437 -73.905643
# 4  Bronx   Riverdale    40.890834 -73.912585

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(neighborhoods['Borough'].unique()),
        neighborhoods.shape[0]
    )
)
# Out:
# The dataframe has 5 boroughs and 306 neighborhoods.

# %% [markdown]
# #### Use geopy library to get the latitude and longitude values of New York City.

# %% [markdown]
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>ny_explorer</em>, as shown below.

# %%
address = 'New York City, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York City are 40.7127281, -74.0060152.

# %% [markdown]
# #### Create a map of New York with neighborhoods superimposed on top.

# %%
# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=18)
folium.Marker([latitude, longitude], popup='New York City').add_to(map_newyork)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Category id for metro stations: 4bf58dd8d48988d1fd931735
#
# Source: https://developer.foursquare.com/docs/resources/categories

# %% [markdown]
# ### Get the metro stations in New York City in radius of 15 km

# %%
CLIENT_ID = 'TM05IWXO3T1QUDJFYCW2JQQUGBGFKWLO4EM12F35YVJDYM3P' # your Foursquare ID
CLIENT_SECRET = 'UKOWS3KCUFGQVF25VKSSDRABC1EMPV2GWPCC2EGP5NA5V0VE' # your Foursquare Secret
VERSION = '20200405' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)

radius = 15000
LIMIT = 200
category_id = '4bf58dd8d48988d1fd931735' # Metro Stations
# Out:
# Your credentails:
# CLIENT_ID: TM05IWXO3T1QUDJFYCW2JQQUGBGFKWLO4EM12F35YVJDYM3P
# CLIENT_SECRET:UKOWS3KCUFGQVF25VKSSDRABC1EMPV2GWPCC2EGP5NA5V0VE

# %%
url = 'https://api.foursquare.com/v2/venues/explore?categoryId={}&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    category_id,
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude,
    longitude, 
    radius,
    LIMIT
)

# %%
stations_list = requests.get(url).json()['response']['groups'][0]['items']
stations_init_df = json_normalize(stations_list)

stations_init_df.head(2)
# Out:
#    reasons.count  \
# 0  0
# 1  0
#
#                                                                                        reasons.items  \
# 0  [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]
# 1  [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]
#
#                        referralId  \
# 0  e-0-5b9400f7b6b04b002c0c38f2-0
# 1  e-0-42829c80f964a5206a221fe3-1
#
#                                                                                                                                                                                                                                     venue.categories  \
# 0  [{'id': '4bf58dd8d48988d1fd931735', 'name': 'Metro Station', 'pluralName': 'Metro Stations', 'shortName': 'Metro', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_', 'suffix': '.png'}, 'primary': True}]
# 1  [{'id': '4bf58dd8d48988d129951735', 'name': 'Train Station', 'pluralName': 'Train Stations', 'shortName': 'Train Station', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_', 'suffix': '.png'}, 'primary': True}]
#
#                    venue.id venue.location.address venue.location.cc  \
# 0  5b9400f7b6b04b002c0c38f2  NaN                    US
# 1  42829c80f964a5206a221fe3  87 E 42nd St           US
#
#   venue.location.city venue.location.country  venue.location.crossStreet  \
# 0  New York            United States          NaN
# 1  New York            United States          btwn Vanderbilt & Park Ave
#
#    venue.location.distance  \
# 0  499
# 1  5088
#
#                                                   venue.location.formattedAddress  \
# 0  [New York, NY 10007, United States]
# 1  [87 E 42nd St (btwn Vanderbilt & Park Ave), New York, NY 10017, United States]
#
#                                                  venue.location.labeledLatLngs  \
# 0  [{'label': 'display', 'lat': 40.71175341389467, 'lng': -74.01179060853417}]
# 1  NaN
#
#    venue.location.lat  venue.location.lng venue.location.neighborhood  \
# 0  40.711753          -74.011791           Financial District
# 1  40.752809          -73.977014           NaN
#
#   venue.location.postalCode venue.location.state  \
# 0  10007                     NY
# 1  10017                     NY
#
#                           venue.name  venue.photos.count venue.photos.groups  \
# 0  MTA Subway - Cortlandt St WTC (1)  0                   []
# 1  Grand Central Terminal             0                   []
#
#   venue.venuePage.id
# 0  NaN
# 1  91385129

# %% [markdown]
# #### Extract station information

# %%
# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng', 'venue.location.distance', 'venue.location.postalCode']
stations_filtered_df = stations_init_df.loc[:, filtered_columns]

# filter the category for each row
stations_filtered_df['venue_type'] = stations_init_df['venue.categories'].apply(lambda x: dict(x[0])['name'])

# clean columns
stations_filtered_df.columns = [col.split('.')[-1] for col in stations_filtered_df.columns]

stations_df = stations_filtered_df[stations_filtered_df['venue_type'] == 'Metro Station']
stations_df = stations_df.drop('categories', axis=1)
stations_df.head()
# Out:
#                                                              name        lat  \
# 0  MTA Subway - Cortlandt St WTC (1)                               40.711753
# 2  World Trade Center Transportation Hub (The Oculus)              40.711599
# 3  MTA Subway - Park Place (2/3)                                   40.712727
# 4  MTA Subway - City Hall (R/W)                                    40.713394
# 5  MTA Subway - Brooklyn Bridge/City Hall/Chambers St (4/5/6/J/Z)  40.712459
#
#          lng  distance postalCode     venue_type
# 0 -74.011791  499       10007      Metro Station
# 2 -74.011465  476       10007      Metro Station
# 3 -74.007763  147       NaN        Metro Station
# 4 -74.006934  107       10038      Metro Station
# 5 -74.005054  86        10007      Metro Station

# %%
stations_df.shape
# Out:
# (98, 6)

# %% [markdown]
# #### Check that all the rows indeed represent a metro station

# %%
#Check that all the rows indeed represent a metro station
stations_df[stations_df['name'].str.find('Station') == -1]
# Out:
#                                                                                        name  \
# 0   MTA Subway - Cortlandt St WTC (1)
# 2   World Trade Center Transportation Hub (The Oculus)
# 3   MTA Subway - Park Place (2/3)
# 4   MTA Subway - City Hall (R/W)
# 5   MTA Subway - Brooklyn Bridge/City Hall/Chambers St (4/5/6/J/Z)
# 6   MTA Subway - Chambers St (A/C/E)
# 7   MTA Subway - World Trade Center (E)
# 8   MTA Subway - Fulton St (A/C/J/Z/2/3/4/5)
# 9   MTA Subway - Chambers St (1/2/3)
# 10  MTA Subway - Cortlandt St (R/W)
# 12  MTA Subway - Wall St (2/3)
# 13  MTA Subway - Wall St (4/5)
# 14  MTA Subway - Canal St (6/J/N/Q/R/W/Z)
# 15  MTA Subway - Canal St (A/C/E)
# 16  MTA Subway - Canal St (1)
# 17  MTA Subway - Bowling Green (4/5)
# 18  MTA Subway - Grand St (B/D)
# 19  MTA Subway - Spring St (6)
# 20  MTA Subway - South Ferry (1)
# 21  MTA Subway - East Broadway (F)
# 22  MTA Subway - Whitehall St (R/W)
# 23  MTA Subway - Spring St (C/E)
# 24  MTA Subway - Prince St (R/W)
# 25  MTA Subway - Broadway/Lafayette St (B/D/F/M)
# 26  MTA Subway - Delancey St/Essex St (F/J/M/Z)
# 27  MTA Subway - Houston St (1)
# 28  MTA Subway - Bleecker St (6)
# 29  MTA Subway - 2nd Ave (F)
# 30  MTA Subway - High St/Brooklyn Bridge (A/C)
# 31  MTA Subway - Clark St (2/3)
# 32  MTA Subway - York St (F)
# 33  MTA Subway - W 4th Street/Washington Square (A/B/C/D/E/F/M)
# 35  MTA Subway - 8th St/NYU (R/W)
# 36  MTA Subway - Astor Pl (6)
# 38  MTA Subway - Christopher St/Sheridan Square (1)
# 40  MTA Subway - Borough Hall/Court St (R/2/3/4/5)
# 41  MTA Subway - 3rd Ave (L)
# 42  MTA Subway - Jay St/MetroTech (A/C/F/R)
# 43  MTA Subway - 14th St/Union Square (4/5/6/L/N/Q/R/W)
# 46  MTA Subway - 1st Ave (L)
# 47  MTA Subway - 14th St (1/2/3)
# 48  MTA Subway - 14th St (F/L/M)
# 49  MTA Subway - 14th St (A/C/E/L)
# 50  MTA Subway - DeKalb Ave (B/Q/R)
# 52  MTA Subway - Hoyt/Schermerhorn Sts (A/C/G)
# 54  MTA Subway - 18th St (1)
# 55  MTA Subway - 23rd St (6)
# 56  MTA Subway - Nevins St (2/3/4/5)
# 57  MTA Subway - 23rd St (R/W)
# 58  MTA Subway - 23rd St (F/M)
# 59  MTA Subway - 23rd St (1)
# 60  MTA Subway - 23rd St (C/E)
# 61  MTA Subway - Fulton St (G)
# 62  MTA Subway - Carroll St (F/G)
# 63  MTA Subway - 28th St (6)
# 64  MTA Subway - 28th St (R/W)
# 65  MTA Subway - Atlantic Ave/Barclays Center (B/D/N/Q/R/2/3/4/5)
# 66  MTA Subway - 28th St (1)
# 67  MTA Subway - Lafayette Ave (C)
# 68  MTA Subway - Marcy Ave (J/M/Z)
# 69  MTA Subway - Bedford Ave (L)
# 70  MTA Subway - 33rd St (6)
# 72  MTA Subway - Clinton/Washington Aves (G)
# 73  MTA Subway - Smith/9th St (F/G)
# 74  IND Culver Viaduct - (F/G) Trains
# 75  MTA Subway - Union St (R)
# 76  MTA Subway - 34th St/Herald Sq (B/D/F/M/N/Q/R/W)
# 77  MTA Subway - 42nd St/Times Square/Port Authority Bus Terminal (A/C/E/N/Q/R/W/S/1/2/3/7)
# 81  MTA Subway - Metropolitan Ave (G)
# 82  MTA Subway - Lorimer St (L)
# 83  MTA Subway - Classon Ave (G)
# 84  MTA Subway - 34th St/Hudson Yards (7)
# 85  MTA Subway - Clinton/Washington Aves (C)
# 86  MTA Subway - Broadway (G)
# 87  MTA Subway - Nassau Ave (G)
# 88  MTA Subway - 7th Ave (B/Q)
# 89  MTA Subway - 42nd St/Bryant Park (B/D/F/M/7)
# 90  MTA Subway - 4th Ave/9th St (F/G/R)
# 91  MTA Subway - 42nd St/Grand Central (4/5/6/7/S)
# 92  MTA Subway - 5th Ave/Bryant Park (7)
# 93  MTA Subway - Lorimer St (J/M)
# 94  MTA Subway - Bedford/Nostrand Aves (G)
# 95  MTA Subway - Grand Army Plaza (2/3)
# 96  MTA Subway - Graham Ave (L)
# 98  MTA Subway - 86th St (4/5/6)
# 99  MTA Subway - Prospect Ave (R)
#
#           lat        lng  distance postalCode     venue_type
# 0   40.711753 -74.011791  499       10007      Metro Station
# 2   40.711599 -74.011465  476       10007      Metro Station
# 3   40.712727 -74.007763  147       NaN        Metro Station
# 4   40.713394 -74.006934  107       10038      Metro Station
# 5   40.712459 -74.005054  86        10007      Metro Station
# 6   40.714086 -74.008584  264       10007      Metro Station
# 7   40.712407 -74.009973  335       10007      Metro Station
# 8   40.710706 -74.009243  353       10038      Metro Station
# 9   40.715531 -74.009288  416       NaN        Metro Station
# 10  40.711806 -74.011610  483       NaN        Metro Station
# 12  40.706513 -74.009463  750       10005      Metro Station
# 13  40.707681 -74.011968  753       10006      Metro Station
# 14  40.718144 -74.000157  779       10013      Metro Station
# 15  40.720656 -74.005098  885       10013      Metro Station
# 16  40.722529 -74.006094  1091      10013      Metro Station
# 17  40.704644 -74.014238  1136      10004      Metro Station
# 18  40.718229 -73.993676  1207      10002      Metro Station
# 19  40.722261 -73.997133  1299      10012      Metro Station
# 20  40.701929 -74.012961  1337      10004      Metro Station
# 21  40.713973 -73.990125  1347      10002      Metro Station
# 22  40.701773 -74.012943  1352      10004      Metro Station
# 23  40.725555 -74.003965  1438      10013      Metro Station
# 24  40.724199 -73.997749  1454      10012      Metro Station
# 25  40.725358 -73.996267  1628      10003      Metro Station
# 26  40.718673 -73.988011  1656      10002      Metro Station
# 27  40.728178 -74.005370  1720      10014      Metro Station
# 28  40.725788 -73.994695  1739      10012      Metro Station
# 29  40.723101 -73.988866  1851      10003      Metro Station
# 30  40.699512 -73.991284  1926      11201      Metro Station
# 31  40.697659 -73.993008  2004      11201      Metro Station
# 32  40.701407 -73.986873  2048      11201      Metro Station
# 33  40.731113 -74.001307  2084      10011      Metro Station
# 35  40.730575 -73.992479  2291      10003      Metro Station
# 36  40.729989 -73.990960  2303      10003      Metro Station
# 38  40.733619 -74.002823  2341      10011      Metro Station
# 40  40.692465 -73.990305  2616      11201      Metro Station
# 41  40.733207 -73.987097  2782      10003      Metro Station
# 42  40.692133 -73.987263  2785      11201      Metro Station
# 43  40.734871 -73.990243  2801      10003      Metro Station
# 46  40.731241 -73.982558  2857      10003      Metro Station
# 47  40.738616 -73.999663  2931      10009      Metro Station
# 48  40.738637 -73.995882  3008      10011      Metro Station
# 49  40.740429 -74.002148  3100      10011      Metro Station
# 50  40.691404 -73.982222  3109      11201      Metro Station
# 52  40.688692 -73.985018  3209      NaN        Metro Station
# 54  40.741083 -73.997705  3233      10011      Metro Station
# 55  40.740159 -73.986446  3471      10010      Metro Station
# 56  40.688195 -73.980433  3481      11201      Metro Station
# 57  40.741392 -73.989101  3495      10010      Metro Station
# 58  40.743011 -73.993003  3545      10001      Metro Station
# 59  40.744093 -73.995716  3598      10011      Metro Station
# 60  40.745285 -73.998506  3679      10039      Metro Station
# 61  40.687111 -73.976392  3792      NaN        Metro Station
# 62  40.679225 -73.995719  3829      11231      Metro Station
# 63  40.743343 -73.984097  3877      10016      Metro Station
# 64  40.745279 -73.988751  3905      10001      Metro Station
# 65  40.684104 -73.978464  3944      11217      Metro Station
# 66  40.747227 -73.993362  3985      10009      Metro Station
# 67  40.686082 -73.973891  4018      11217      Metro Station
# 68  40.708480 -73.957968  4081      11211      Metro Station
# 69  40.717713 -73.957695  4114      11211      Metro Station
# 70  40.746213 -73.981914  4245      10016      Metro Station
# 72  40.688327 -73.965757  4349      11205      Metro Station
# 73  40.674128 -73.996774  4367      11231      Metro Station
# 74  40.673977 -73.996501  4387      11215      Metro Station
# 75  40.677173 -73.983136  4403      11215      Metro Station
# 76  40.749937 -73.987965  4413      10018      Metro Station
# 77  40.755891 -73.987890  5042      10036      Metro Station
# 81  40.713857 -73.951607  4592      11211      Metro Station
# 82  40.714033 -73.951366  4613      11211      Metro Station
# 83  40.688918 -73.960137  4692      11205      Metro Station
# 84  40.754897 -74.000690  4715      10001      Metro Station
# 85  40.683280 -73.965158  4757      11238      Metro Station
# 86  40.705500 -73.950180  4779      11211      Metro Station
# 87  40.723806 -73.950801  4818      11222      Metro Station
# 88  40.677373 -73.972605  4841      11238      Metro Station
# 89  40.753690 -73.984859  4896      10036      Metro Station
# 90  40.670102 -73.989461  4946      11215      Metro Station
# 91  40.751833 -73.976842  5000      10017      Metro Station
# 92  40.753897 -73.981777  5018      10009      Metro Station
# 93  40.703972 -73.947567  5027      11206      Metro Station
# 94  40.689541 -73.954069  5087      11205      Metro Station
# 95  40.675184 -73.971031  5117      11238      Metro Station
# 96  40.714669 -73.944362  5206      11211      Metro Station
# 98  40.779554 -73.955613  8567      10028      Metro Station
# 99  40.665070 -73.993195  5414      11215      Metro Station

# %%
#Indeed the above rows are 'parking' places for trains. They need to be removed from the dataframe
# Keep only the stations that their name contains 'Station' 

stations_df = stations_df[stations_df['name'].str.contains('Station')]
stations_df.shape
# Out:
# (12, 6)

# %%
stations_df.head()
# Out:
#                                name        lat        lng  distance  \
# 11  World Trade Center PATH Station  40.711807 -74.011687  489
# 34  Christopher Street PATH Station  40.732937 -74.006905  2250
# 37  Exchange Place PATH Station      40.716249 -74.033207  2327
# 39  9th Street PATH Station          40.734119 -73.998916  2455
# 44  Newport PATH Station             40.726838 -74.034201  2849
#
#    postalCode     venue_type
# 11  10006      Metro Station
# 34  10014      Metro Station
# 37  07302      Metro Station
# 39  10011      Metro Station
# 44  07310      Metro Station

# %%
stations_df.rename(columns={'name': 'station',
                            'distance': 'Distance from Center',
                            'postalCode': 'Postal Code',
                            'venue_type': 'Venue Type'},
                   inplace=True)

stations_df.reset_index(drop=True, inplace=True)

print(stations_df.info())
stations_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
# station                 12 non-null object
# lat                     12 non-null float64
# lng                     12 non-null float64
# Distance from Center    12 non-null int64
# Postal Code             12 non-null object
# Venue Type              12 non-null object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 656.0+ bytes
# None
#                            station        lat        lng  \
# 0  World Trade Center PATH Station  40.711807 -74.011687
# 1  Christopher Street PATH Station  40.732937 -74.006905
# 2  Exchange Place PATH Station      40.716249 -74.033207
# 3  9th Street PATH Station          40.734119 -73.998916
# 4  Newport PATH Station             40.726838 -74.034201
#
#    Distance from Center Postal Code     Venue Type
# 0  489                   10006       Metro Station
# 1  2250                  10014       Metro Station
# 2  2327                  07302       Metro Station
# 3  2455                  10011       Metro Station
# 4  2849                  07310       Metro Station

# %% [markdown]
# #### Visualize the metro stations on a map of New York

# %%
# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
for lat, lng, station in zip(stations_df['lat'],
                          stations_df['lng'],
                          stations_df['station']):
    label = '{}'.format(station)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False
    ).add_to(map_newyork)
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Get the gyms near the stations
#
# Category id for Gym / Fitness Center: 4bf58dd8d48988d175941735
#
# Source: https://developer.foursquare.com/docs/resources/categories
#
# Function to create a dataframe with the results gathered from Foursquare API on a specific category

# %%
#CLIENT_ID = 'TM05IWXO3T1QUDJFYCW2JQQUGBGFKWLO4EM12F35YVJDYM3P' # your Foursquare ID
#CLIENT_SECRET = 'UKOWS3KCUFGQVF25VKSSDRABC1EMPV2GWPCC2EGP5NA5V0VE' # your Foursquare Secret
#VERSION = '20200405' # Foursquare API version

#LIMIT = 200
#category_id = '4bf58dd8d48988d175941735' # Gym / Fitness Center

# %%
def getNearbyGyms(categoryId, stations, latitudes, longitudes, radius=750):
    
    print('Finding gyms near New York metro stations, please wait...\n')
    
    gyms_list=[]
    for station, lat, lng in zip(stations, latitudes, longitudes):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?categoryId={}&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            categoryId,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()['response']['groups'][0]['items']
        
        # return only relevant information for each nearby gym
        gyms_list.append([(
            station,
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],
            v['venue']['location']['distance'],
            v['venue']['categories'][0]['name']
        ) for v in results])

    nearby_gyms_df = pd.DataFrame([item for venue_list in gyms_list for item in venue_list])
    nearby_gyms_df.columns = [
                  'station',
                  'lat',
                  'lng',
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude',
                  'Distance from Station',
                  'Venue Category']
    print('Finished')
    return(nearby_gyms_df)

# %% [markdown]
# #### Use the function to gather information about existing gyms in a radius of 750m around each metro station in New York

# %%
categoryId = '4bf58dd8d48988d175941735' # Gym / Fitness Center
gyms_venues_df = getNearbyGyms(categoryId, stations=stations_df['station'], latitudes=stations_df['lat'], longitudes=stations_df['lng'])
# Out:
# Finding gyms near New York metro stations, please wait...
#
# Finished

# %%
gyms_venues_df.head()
# Out:
#                            station        lat        lng  \
# 0  World Trade Center PATH Station  40.711807 -74.011687
# 1  World Trade Center PATH Station  40.711807 -74.011687
# 2  World Trade Center PATH Station  40.711807 -74.011687
# 3  World Trade Center PATH Station  40.711807 -74.011687
# 4  World Trade Center PATH Station  40.711807 -74.011687
#
#                        Venue  Venue Latitude  Venue Longitude  \
# 0  The Class by Taryn Toomey  40.712753      -74.008734
# 1  Equinox Brookfield Place   40.712704      -74.014995
# 2  Crunch - FiDi              40.708614      -74.010013
# 3  Equinox Tribeca            40.714099      -74.009686
# 4  Exceed Physical Culture    40.715629      -74.007992
#
#    Distance from Station        Venue Category
# 0  270                    Gym / Fitness Center
# 1  296                    Gym / Fitness Center
# 2  382                    Gym / Fitness Center
# 3  305                    Gym / Fitness Center
# 4  527                    Gym / Fitness Center

# %% [markdown]
# ##### Let's check the categories of venues that were returned for each neighborhood

# %%
gyms_venues_df.groupby(['Venue Category']).count()
# Out:
#                                           station  lat  lng  Venue  \
# Venue Category
# Advertising Agency                        1        1    1    1
# Boxing Gym                                12       12   12   12
# Building                                  3        3    3    3
# Construction & Landscaping                1        1    1    1
# Cycle Studio                              9        9    9    9
# Dance Studio                              3        3    3    3
# Gym                                       220      220  220  220
# Gym / Fitness Center                      430      430  430  430
# Gym Pool                                  2        2    2    2
# Martial Arts Dojo                         34       34   34   34
# Medical Center                            6        6    6    6
# Park                                      1        1    1    1
# Pilates Studio                            13       13   13   13
# Pool                                      1        1    1    1
# Residential Building (Apartment / Condo)  2        2    2    2
# Spa                                       1        1    1    1
# Tennis Court                              1        1    1    1
# Track                                     4        4    4    4
# Yoga Studio                               80       80   80   80
#
#                                           Venue Latitude  Venue Longitude  \
# Venue Category
# Advertising Agency                        1               1
# Boxing Gym                                12              12
# Building                                  3               3
# Construction & Landscaping                1               1
# Cycle Studio                              9               9
# Dance Studio                              3               3
# Gym                                       220             220
# Gym / Fitness Center                      430             430
# Gym Pool                                  2               2
# Martial Arts Dojo                         34              34
# Medical Center                            6               6
# Park                                      1               1
# Pilates Studio                            13              13
# Pool                                      1               1
# Residential Building (Apartment / Condo)  2               2
# Spa                                       1               1
# Tennis Court                              1               1
# Track                                     4               4
# Yoga Studio                               80              80
#
#                                           Distance from Station
# Venue Category
# Advertising Agency                        1
# Boxing Gym                                12
# Building                                  3
# Construction & Landscaping                1
# Cycle Studio                              9
# Dance Studio                              3
# Gym                                       220
# Gym / Fitness Center                      430
# Gym Pool                                  2
# Martial Arts Dojo                         34
# Medical Center                            6
# Park                                      1
# Pilates Studio                            13
# Pool                                      1
# Residential Building (Apartment / Condo)  2
# Spa                                       1
# Tennis Court                              1
# Track                                     4
# Yoga Studio                               80

# %% [markdown]
# #### We will only keep the two categories [Gym, Gym / Fitness Center]

# %%
gyms_venues_df = gyms_venues_df[gyms_venues_df['Venue Category'].isin(['Gym', 'Gym / Fitness Center'])]
gyms_venues_df.head()
# Out:
#                            station        lat        lng  \
# 0  World Trade Center PATH Station  40.711807 -74.011687
# 1  World Trade Center PATH Station  40.711807 -74.011687
# 2  World Trade Center PATH Station  40.711807 -74.011687
# 3  World Trade Center PATH Station  40.711807 -74.011687
# 4  World Trade Center PATH Station  40.711807 -74.011687
#
#                        Venue  Venue Latitude  Venue Longitude  \
# 0  The Class by Taryn Toomey  40.712753      -74.008734
# 1  Equinox Brookfield Place   40.712704      -74.014995
# 2  Crunch - FiDi              40.708614      -74.010013
# 3  Equinox Tribeca            40.714099      -74.009686
# 4  Exceed Physical Culture    40.715629      -74.007992
#
#    Distance from Station        Venue Category
# 0  270                    Gym / Fitness Center
# 1  296                    Gym / Fitness Center
# 2  382                    Gym / Fitness Center
# 3  305                    Gym / Fitness Center
# 4  527                    Gym / Fitness Center

# %% [markdown]
# #### Make sure unwanted venues were removed

# %%
gyms_venues_df.groupby(['Venue Category']).count().head(10)
# Out:
#                       station  lat  lng  Venue  Venue Latitude  \
# Venue Category
# Gym                   220      220  220  220    220
# Gym / Fitness Center  430      430  430  430    430
#
#                       Venue Longitude  Distance from Station
# Venue Category
# Gym                   220              220
# Gym / Fitness Center  430              430

# %% [markdown]
# #### Add distance from each metro station to the nearest gym and number of existing gyms in its vicinity
#
# Add to the data frame the minimum distance of every station to the gyms in its vicinity

# %%
gyms_venues_min_df = pd.merge(gyms_venues_df,
                              pd.DataFrame(gyms_venues_df.groupby('station')['Distance from Station'].min()),
                              on='station', how='inner')

# %%
gyms_venues_min_df.head()
# Out:
#                            station        lat        lng  \
# 0  World Trade Center PATH Station  40.711807 -74.011687
# 1  World Trade Center PATH Station  40.711807 -74.011687
# 2  World Trade Center PATH Station  40.711807 -74.011687
# 3  World Trade Center PATH Station  40.711807 -74.011687
# 4  World Trade Center PATH Station  40.711807 -74.011687
#
#                        Venue  Venue Latitude  Venue Longitude  \
# 0  The Class by Taryn Toomey  40.712753      -74.008734
# 1  Equinox Brookfield Place   40.712704      -74.014995
# 2  Crunch - FiDi              40.708614      -74.010013
# 3  Equinox Tribeca            40.714099      -74.009686
# 4  Exceed Physical Culture    40.715629      -74.007992
#
#    Distance from Station_x        Venue Category  Distance from Station_y
# 0  270                      Gym / Fitness Center  47
# 1  296                      Gym / Fitness Center  47
# 2  382                      Gym / Fitness Center  47
# 3  305                      Gym / Fitness Center  47
# 4  527                      Gym / Fitness Center  47

# %% [markdown]
# #### Add the number of already existing gyms in the vicinity of each station

# %%
gyms_venues_min_count_df = pd.merge(gyms_venues_min_df,
                           pd.DataFrame(gyms_venues_min_df.groupby(['station']).count())['lat'],
                           on='station', how='inner')

# %%
gyms_venues_min_count_df.head()
# Out:
#                            station      lat_x        lng  \
# 0  World Trade Center PATH Station  40.711807 -74.011687
# 1  World Trade Center PATH Station  40.711807 -74.011687
# 2  World Trade Center PATH Station  40.711807 -74.011687
# 3  World Trade Center PATH Station  40.711807 -74.011687
# 4  World Trade Center PATH Station  40.711807 -74.011687
#
#                        Venue  Venue Latitude  Venue Longitude  \
# 0  The Class by Taryn Toomey  40.712753      -74.008734
# 1  Equinox Brookfield Place   40.712704      -74.014995
# 2  Crunch - FiDi              40.708614      -74.010013
# 3  Equinox Tribeca            40.714099      -74.009686
# 4  Exceed Physical Culture    40.715629      -74.007992
#
#    Distance from Station_x        Venue Category  Distance from Station_y  \
# 0  270                      Gym / Fitness Center  47
# 1  296                      Gym / Fitness Center  47
# 2  382                      Gym / Fitness Center  47
# 3  305                      Gym / Fitness Center  47
# 4  527                      Gym / Fitness Center  47
#
#    lat_y
# 0  95
# 1  95
# 2  95
# 3  95
# 4  95

# %% [markdown]
# #### Giving appropriate names to the dataframe columns

# %%
gyms_df = gyms_venues_min_count_df.rename(columns={'lat_x': 'lat', 'Distance from Station_x': 'Distance from Station',
                                                   'Distance from Station_y': 'Min Distance from Station',
                                                   'lat_y': 'Gym Count'})
gyms_df.head(15)
# Out:
#                             station        lat        lng  \
# 0   World Trade Center PATH Station  40.711807 -74.011687
# 1   World Trade Center PATH Station  40.711807 -74.011687
# 2   World Trade Center PATH Station  40.711807 -74.011687
# 3   World Trade Center PATH Station  40.711807 -74.011687
# 4   World Trade Center PATH Station  40.711807 -74.011687
# 5   World Trade Center PATH Station  40.711807 -74.011687
# 6   World Trade Center PATH Station  40.711807 -74.011687
# 7   World Trade Center PATH Station  40.711807 -74.011687
# 8   World Trade Center PATH Station  40.711807 -74.011687
# 9   World Trade Center PATH Station  40.711807 -74.011687
# 10  World Trade Center PATH Station  40.711807 -74.011687
# 11  World Trade Center PATH Station  40.711807 -74.011687
# 12  World Trade Center PATH Station  40.711807 -74.011687
# 13  World Trade Center PATH Station  40.711807 -74.011687
# 14  World Trade Center PATH Station  40.711807 -74.011687
#
#                               Venue  Venue Latitude  Venue Longitude  \
# 0   The Class by Taryn Toomey        40.712753      -74.008734
# 1   Equinox Brookfield Place         40.712704      -74.014995
# 2   Crunch - FiDi                    40.708614      -74.010013
# 3   Equinox Tribeca                  40.714099      -74.009686
# 4   Exceed Physical Culture          40.715629      -74.007992
# 5   Physique 57                      40.706844      -74.013014
# 6   Equinox Wall Street              40.707273      -74.010543
# 7   Xtend Barre Tribeca              40.715227      -74.010385
# 8   American Express Fitness Center  40.713752      -74.014276
# 9   Trinity Boxing Club              40.708911      -74.013379
# 10  Just Train                       40.709470      -74.009840
# 11  CrossFit 212 TriBeCa             40.714537      -74.005999
# 12  Asphalt Green                    40.716035      -74.014815
# 13  Pure Barre                       40.716066      -74.008442
# 14  Crossfit Wall Street             40.705544      -74.012139
#
#     Distance from Station        Venue Category  Min Distance from Station  \
# 0   270                    Gym / Fitness Center  47
# 1   296                    Gym / Fitness Center  47
# 2   382                    Gym / Fitness Center  47
# 3   305                    Gym / Fitness Center  47
# 4   527                    Gym / Fitness Center  47
# 5   563                    Gym / Fitness Center  47
# 6   513                    Gym                   47
# 7   396                    Gym / Fitness Center  47
# 8   307                    Gym / Fitness Center  47
# 9   352                    Gym                   47
# 10  303                    Gym                   47
# 11  568                    Gym                   47
# 12  539                    Gym / Fitness Center  47
# 13  547                    Gym / Fitness Center  47
# 14  698                    Gym                   47
#
#     Gym Count
# 0   95
# 1   95
# 2   95
# 3   95
# 4   95
# 5   95
# 6   95
# 7   95
# 8   95
# 9   95
# 10  95
# 11  95
# 12  95
# 13  95
# 14  95

# %% [markdown]
# #### Retaining only the necessary columns

# %%
gyms_df = gyms_df[['station', 'lat', 'lng', 'Min Distance from Station', 'Gym Count']].drop_duplicates()

# %%
gyms_df.head(10)
# Out:
#                                        station        lat        lng  \
# 0    World Trade Center PATH Station            40.711807 -74.011687
# 95   Christopher Street PATH Station            40.732937 -74.006905
# 132  Exchange Place PATH Station                40.716249 -74.033207
# 158  9th Street PATH Station                    40.734119 -73.998916
# 228  Newport PATH Station                       40.726838 -74.034201
# 252  14th Street PATH Station                   40.737438 -73.996931
# 332  Grove Street PATH Station                  40.719785 -74.042707
# 377  Hoboken PATH Station                       40.735691 -74.029110
# 400  33rd St PATH Station                       40.748613 -73.988417
# 479  MTA Subway - 34th St/Penn Station (1/2/3)  40.750996 -73.990688
#
#      Min Distance from Station  Gym Count
# 0    47                         95
# 95   83                         37
# 132  155                        26
# 158  66                         70
# 228  48                         24
# 252  42                         80
# 332  67                         45
# 377  79                         23
# 400  60                         79
# 479  98                         83

# %% [markdown]
# #### Checking how many metro stations are there with existing gym

# %%
gyms_df.shape
# Out:
# (12, 5)

# %% [markdown]
# #### We will now merge the initial stations_df dataframe with the previously created gyms_df and assign 10000 to 'Min Distance from Station' and 0 to 'Gym Count'

# %%
missing_stations_df = pd.merge(stations_df[['station', 'lat', 'lng']], gyms_df,
                                    on='station', how='left')
missing_stations_df[missing_stations_df['Gym Count'].isnull()]
# Out:
# Empty DataFrame
# Columns: [station, lat_x, lng_x, lat_y, lng_y, Min Distance from Station, Gym Count]
# Index: []

# %% [markdown]
# #### This shows that no stations are having 0 gyms around it.

# %%
stations_gyms_grouped_df = gyms_df.copy()

# %%
stations_gyms_grouped_df.shape
# Out:
# (12, 5)

# %%
stations_gyms_grouped_df.head()
# Out:
#                              station        lat        lng  \
# 0    World Trade Center PATH Station  40.711807 -74.011687
# 95   Christopher Street PATH Station  40.732937 -74.006905
# 132  Exchange Place PATH Station      40.716249 -74.033207
# 158  9th Street PATH Station          40.734119 -73.998916
# 228  Newport PATH Station             40.726838 -74.034201
#
#      Min Distance from Station  Gym Count
# 0    47                         95
# 95   83                         37
# 132  155                        26
# 158  66                         70
# 228  48                         24

# %% [markdown]
# #### Normalize Data [Min Distance from Station, Gym Count]
# Data Standardization give data zero mean and unit variance

# %%
print('All stations mean distance from any gym: ', stations_gyms_grouped_df['Min Distance from Station'].mean())
print('All stations maximum distance from any gym: ',stations_gyms_grouped_df['Min Distance from Station'].max())
print('All stations minimum distance from any gym: ', stations_gyms_grouped_df['Min Distance from Station'].min())
print('All stations mean of number of existing gyms: ', stations_gyms_grouped_df['Gym Count'].mean())
print('All stations maximum number of existing gyms: ', stations_gyms_grouped_df['Gym Count'].max())
print('All stations minimum number of existing gyms: ', stations_gyms_grouped_df['Gym Count'].min())
# Out:
# All stations mean distance from any gym:  84.5
# All stations maximum distance from any gym:  245
# All stations minimum distance from any gym:  24
# All stations mean of number of existing gyms:  54.166666666666664
# All stations maximum number of existing gyms:  95
# All stations minimum number of existing gyms:  4

# %%
stations_gyms_grouped_df['Norm Min Distance from Station'] = (stations_gyms_grouped_df['Min Distance from Station'] - \
                                                              stations_gyms_grouped_df['Min Distance from Station'].mean()) / \
                                                             (stations_gyms_grouped_df['Min Distance from Station'].max() - \
                                                              stations_gyms_grouped_df['Min Distance from Station'].min())
stations_gyms_grouped_df['Norm Gym Count'] = (stations_gyms_grouped_df['Gym Count'] - stations_gyms_grouped_df['Gym Count'].mean()) / \
                                             (stations_gyms_grouped_df['Gym Count'].max() - stations_gyms_grouped_df['Gym Count'].min())

# %%
stations_gyms_grouped_df['Gym Count'] = stations_gyms_grouped_df['Gym Count'].astype(int)

# %%
stations_gyms_grouped_df.reset_index(drop=True, inplace=True)

# %%
stations_gyms_grouped_df.head(10)
# Out:
#                                      station        lat        lng  \
# 0  World Trade Center PATH Station            40.711807 -74.011687
# 1  Christopher Street PATH Station            40.732937 -74.006905
# 2  Exchange Place PATH Station                40.716249 -74.033207
# 3  9th Street PATH Station                    40.734119 -73.998916
# 4  Newport PATH Station                       40.726838 -74.034201
# 5  14th Street PATH Station                   40.737438 -73.996931
# 6  Grove Street PATH Station                  40.719785 -74.042707
# 7  Hoboken PATH Station                       40.735691 -74.029110
# 8  33rd St PATH Station                       40.748613 -73.988417
# 9  MTA Subway - 34th St/Penn Station (1/2/3)  40.750996 -73.990688
#
#    Min Distance from Station  Gym Count  Norm Min Distance from Station  \
# 0  47                         95        -0.169683
# 1  83                         37        -0.006787
# 2  155                        26         0.319005
# 3  66                         70        -0.083710
# 4  48                         24        -0.165158
# 5  42                         80        -0.192308
# 6  67                         45        -0.079186
# 7  79                         23        -0.024887
# 8  60                         79        -0.110860
# 9  98                         83         0.061086
#
#    Norm Gym Count
# 0  0.448718
# 1 -0.188645
# 2 -0.309524
# 3  0.173993
# 4 -0.331502
# 5  0.283883
# 6 -0.100733
# 7 -0.342491
# 8  0.272894
# 9  0.316850

# %% [markdown]
# ### K-Means Clustering

# %% [markdown]
# #### Prepare the dataframe to be used in K-Means algorithm

# %%
gyms_clustering_df = stations_gyms_grouped_df.drop(['station', 'lat', 'lng', 'Min Distance from Station', 'Gym Count'], 1)

# %%
gyms_clustering_df.head()
# Out:
#    Norm Min Distance from Station  Norm Gym Count
# 0 -0.169683                        0.448718
# 1 -0.006787                       -0.188645
# 2  0.319005                       -0.309524
# 3 -0.083710                        0.173993
# 4 -0.165158                       -0.331502

# %% [markdown]
# #### Cluster Locations (Metro stations) in New York (K-Means Clustering)
# The KMeans class has many parameters that can be used, but we will be using these three:
#
# init: Initialization method of the centroids.
#
# Value will be: "k-means++"
#
# k-means++: Selects initial cluster centers for k-mean clustering in a smart way to speed up convergence.
#
# n_clusters: The number of clusters to form as well as the number of centroids to generate.
#
# Value will be: 4 (since we have 4 centers)
#
# n_init: Number of time the k-means algorithm will be run with different centroid seeds. The final results will be the best output of n_init consecutive runs in terms of inertia.
#
# Value will be: 12

# %% [markdown]
# #### Use the Elbow method to find the best k for clustering

# %%
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt

distorsions = []
for k in range(1, 10):
    kmeans = KMeans(init="k-means++", n_clusters=k, random_state=0, n_init = 12, max_iter=300, tol=0.00001)
    kmeans.fit(gyms_clustering_df)
    distorsions.append(kmeans.inertia_)

fig, ax = subplots(figsize=(8, 4))
ax.plot(range(1, 10), distorsions, '--bo')
ax.set_xlabel('Number of Clusters', fontsize=12)
ax.set_ylabel('Distortion', fontsize=12)
plt.grid(True)
plt.title('K-Means Elbow curve', fontsize='18')
plt.tight_layout()
plt.show()

# %% [markdown]
# The elbow graph, although not very steep, presents an elbow point at 3 number of clusters.

# %% [markdown]
# #### Run k-means to cluster the station areas to 3 clusters

# %%
# venues_grouped_clustering_df = venues_grouped_df.drop('station', 1)
kmeans = KMeans(init="k-means++", n_clusters=3, random_state=0, n_init = 12, max_iter=300, tol=0.0001)
kmeans.fit(gyms_clustering_df)

kmeans.labels_
# Out:
# array([0, 2, 1, 0, 2, 0, 2, 2, 0, 0, 0, 1], dtype=int32)

# %% [markdown]
# ### K-Means Clustering Results

# %% [markdown]
# ##### Create a new dataframe that includes the resulted clusters and relevant metro station information

# %%
# add clustering labels
stations_gyms_grouped_df.insert(1, 'Cluster Label', kmeans.labels_)

# %%
stations_gyms_grouped_df.head()
# Out:
#                            station  Cluster Label        lat        lng  \
# 0  World Trade Center PATH Station  0              40.711807 -74.011687
# 1  Christopher Street PATH Station  2              40.732937 -74.006905
# 2  Exchange Place PATH Station      1              40.716249 -74.033207
# 3  9th Street PATH Station          0              40.734119 -73.998916
# 4  Newport PATH Station             2              40.726838 -74.034201
#
#    Min Distance from Station  Gym Count  Norm Min Distance from Station  \
# 0  47                         95        -0.169683
# 1  83                         37        -0.006787
# 2  155                        26         0.319005
# 3  66                         70        -0.083710
# 4  48                         24        -0.165158
#
#    Norm Gym Count
# 0  0.448718
# 1 -0.188645
# 2 -0.309524
# 3  0.173993
# 4 -0.331502

# %% [markdown]
# #### Visualize the metro stations clusters on a map of New York

# %%
cluster_colors = ['green', 'red', 'blue'] 

map_clusters = folium.Map(location=[latitude, longitude], zoom_start=12)

markers_colors = []
for lat, lon, poi, cluster in zip(stations_gyms_grouped_df['lat'], stations_gyms_grouped_df['lng'], 
                                  stations_gyms_grouped_df['station'], stations_gyms_grouped_df['Cluster Label']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster + 1), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=cluster_colors[cluster],
        fill=True,
        fill_color=cluster_colors[cluster],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##### Now visualize the (normalized) clusters distribution on a scatter plot along with their final corresponding centroids

# %%
fig, ax = subplots(figsize=(8, 6))
for label in kmeans.labels_:
    plt.scatter(stations_gyms_grouped_df[stations_gyms_grouped_df['Cluster Label'] == label]['Norm Min Distance from Station'],
                stations_gyms_grouped_df[stations_gyms_grouped_df['Cluster Label'] == label]['Norm Gym Count'],
                marker='x', color=cluster_colors[label])
    
for centroid in kmeans.cluster_centers_:
    plt.scatter(centroid[0], centroid[1], s=130, marker="*", color='black')
    
ax.set_xlabel('Normalized Minimum Distance from Station', fontsize=12)
ax.set_ylabel('Normalized Gym Count', fontsize=12)
plt.title('Clusters and Centroids', fontsize='18')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Show the Metro stations that correspond to each cluster

# %% [markdown]
# ##### Cluster 1 (LOW potential)
#
# There are already many existing gyms in the area and the nearest gym is in most cases in a relatively short distance from the station

# %%
stations_gyms_grouped_df.loc[stations_gyms_grouped_df['Cluster Label'] == 0]
# Out:
#                                       station  Cluster Label        lat  \
# 0   World Trade Center PATH Station            0              40.711807
# 3   9th Street PATH Station                    0              40.734119
# 5   14th Street PATH Station                   0              40.737438
# 8   33rd St PATH Station                       0              40.748613
# 9   MTA Subway - 34th St/Penn Station (1/2/3)  0              40.750996
# 10  MTA Subway - 34th St/Penn Station (A/C/E)  0              40.751995
#
#           lng  Min Distance from Station  Gym Count  \
# 0  -74.011687  47                         95
# 3  -73.998916  66                         70
# 5  -73.996931  42                         80
# 8  -73.988417  60                         79
# 9  -73.990688  98                         83
# 10 -73.992888  24                         84
#
#     Norm Min Distance from Station  Norm Gym Count
# 0  -0.169683                        0.448718
# 3  -0.083710                        0.173993
# 5  -0.192308                        0.283883
# 8  -0.110860                        0.272894
# 9   0.061086                        0.316850
# 10 -0.273756                        0.327839

# %% [markdown]
# ##### Cluster 2 (HIGH potential)
#
# There are not many already existing gyms in the area and the nearest gym is in most cases relatively not in a short distance to the metro station

# %%
stations_gyms_grouped_df.loc[stations_gyms_grouped_df['Cluster Label'] == 1]
# Out:
#                         station  Cluster Label        lat        lng  \
# 2   Exchange Place PATH Station  1              40.716249 -74.033207
# 11  Journal Square PATH Station  1              40.732037 -74.062827
#
#     Min Distance from Station  Gym Count  Norm Min Distance from Station  \
# 2   155                        26         0.319005
# 11  245                        4          0.726244
#
#     Norm Gym Count
# 2  -0.309524
# 11 -0.551282

# %% [markdown]
# ##### Cluster 3 (AVERAGE potential)
#
# Although not a prohibitive metro station to open a gym in its vicinity, there is already a fair number of gyms in the area and the nearest one is not far from the metro station

# %%
stations_gyms_grouped_df.loc[stations_gyms_grouped_df['Cluster Label'] == 2]
# Out:
#                            station  Cluster Label        lat        lng  \
# 1  Christopher Street PATH Station  2              40.732937 -74.006905
# 4  Newport PATH Station             2              40.726838 -74.034201
# 6  Grove Street PATH Station        2              40.719785 -74.042707
# 7  Hoboken PATH Station             2              40.735691 -74.029110
#
#    Min Distance from Station  Gym Count  Norm Min Distance from Station  \
# 1  83                         37        -0.006787
# 4  48                         24        -0.165158
# 6  67                         45        -0.079186
# 7  79                         23        -0.024887
#
#    Norm Gym Count
# 1 -0.188645
# 4 -0.331502
# 6 -0.100733
# 7 -0.342491

# %% [markdown]
# ### Discussion

# %% [markdown]
# Clusters of areas (in our case Metro stations) were identified as groups of similar in their potential locations for opening a gym.
#
# Possible areas that were not in the Foursquare database should also be examined so that it can be determined if it is just lack of data about these stations or indeed there are no gyms in the vicinity of the stations. A lot more factors can be considered when choosing an appropriate location. Some examples of extra factors can be:
#
# 1) Population density in the area
#
# 2) Number of businesses operating in the area (people may want to go to a gym close to work)
#
# 3) Average age and household income in the area
#
# 4) Property prices in the area

# %% [markdown]
# ### Conclusion

# %% [markdown]
# The above results can be a good starting point for a prospective businessman that is interested in opening a gym. Similar methodology can be used for other types of businesses probably with customized criteria.
#
# With the availability of a number of different tools and Machine Learning algorithms, it is possible to find solutions (or possible solutions) to an ever increasing number of problems and queries.
#
# And it is getting better and better!
